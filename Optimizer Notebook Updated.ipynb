# %%
from __future__ import (division, unicode_literals, absolute_import,
                        print_function)

from ema_workbench import (Model, ScalarOutcome, TimeSeriesOutcome, perform_experiments,
                           RealParameter, CategoricalParameter, IntegerParameter, ema_logging)

from ema_workbench.connectors.vensim import VensimModel

import pandas as pd
import math
import numpy as np
# Out:
# c:\Users\pkane\.conda\envs\prj-lmr-scistack\lib\site-packages\ema_workbench\em_framework\evaluators.py:21: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn(
# c:\Users\pkane\.conda\envs\prj-lmr-scistack\lib\site-packages\ema_workbench\connectors\__init__.py:27: ImportWarning: netlogo connector not available
#   warnings.warn("netlogo connector not available", ImportWarning)

# %%
def row_writer(data, policy_name, start, max_by, max_value, interpolate=True, sub_1="", sub_2="", sub_3=""):
    target_row = (data['Policy']==policy_name) & (data['Subscript 1']==sub_1) & (data['Subscript 2']==sub_2) & (data['Subscript 3']==sub_3)

    data.loc[target_row, "2020":"2050"]=(max_value/100)*np.concatenate((np.zeros(start-2020),[i/(max_by) for i in list(range(0, min(max_by, 2050-start)))],np.ones(max(31-start-max_by+2020, 0))))

# %%
def policy_writer(**kwargs):
    policies = pd.DataFrame(columns=['policy', 'sub_1', 'sub_2', 'sub_3', 'start', 'max_by', 'max_value'])
    for key, value in kwargs.items():
        ids=key.split('__')
        if(((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])).any()==False):
            policies.loc[len(policies.index)] = [ids[0], ids[1], ids[2], ids[3], 0, 0, 0]
        
        
        if(ids[-1]=='start'):
            policies.loc[((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])), 'start']=value
        elif(ids[-1]=='maxby'):
            policies.loc[((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])), 'max_by']=value
        elif(ids[-1]=='maxval'):
            policies.loc[((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])), 'max_value']=value
    print(policies)
    read_data = pd.read_csv('C:\\Users\\pkane\\Documents\\eps-louisiana-3.2.1\\eps-louisiana-3.2.1\\InputData\\plcy-schd\\FoPITY\\FoPITY-1-default.csv',
        keep_default_na=False)
    for index, policy in policies.iterrows():
        row_writer(data=read_data, 
                   policy_name=policy['policy'].replace('_', ' '), 
                   start=policy['start'],
                   max_by=policy['max_by'],
                   max_value=policy['max_value'],
                   sub_1=policy['sub_1'].replace('_', ' '),
                   sub_2=policy['sub_2'].replace('_', ' '),
                   sub_3=policy['sub_3'].replace('_', ' ')
                   )
    read_data.to_csv('FoPITY-1.csv',
                     index=False)
    read_data.to_csv('C:\\Users\\pkane\\Documents\\eps-louisiana-3.2.1\\eps-louisiana-3.2.1\\InputData\\plcy-schd\\FoPITY\\FoPITY-1.csv',
                     index=False)
    
    
def run_inner_model():
    wd = 'C:\\Users\\pkane\\Documents\\eps-louisiana-3.2.1\\eps-louisiana-3.2.1'
    innerModel = VensimModel("simpleModel", wd=wd,
                              model_file='EPS CAP.vpmx')
    innerModel.uncertainties = [RealParameter('xdata', 0, 1)]

    innerModel.outcomes = [TimeSeriesOutcome('Total CO2e Emissions'),
                           TimeSeriesOutcome('BAU Total CO2e Emissions'),
                           TimeSeriesOutcome('Output Social Benefits from Emissions Reduction'),
                           TimeSeriesOutcome('Total Change In CapEx and OpEx'),
                           TimeSeriesOutcome('Output Change in Domestic Jobs'),
                           TimeSeriesOutcome('Output Change in GDP')
                           ]

    inner_results = perform_experiments(innerModel, 1)

    inner_experiments, inner_outcomes = inner_results

    actual_outcomes = {'Emissions':np.mean(inner_outcomes['Total CO2e Emissions'][0][0:15]),
                      'Cost': np.mean(inner_outcomes['Output Social Benefits from Emissions Reduction'][0][0:15]),
                      'Cobenefits':np.mean(inner_outcomes['Total Change In CapEx and OpEx'][0][0:15])}
    print(actual_outcomes)

    return actual_outcomes

def policy_model(**policies):
    print("Running")
    policy_writer(**policies)
    return run_inner_model()

# %%
policy_model(elec_renewable_portfolio_standards________maxval=100, 
elec_renewable_portfolio_standards________start=2025,
elec_renewable_portfolio_standards________maxby=10)
# Out:
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025      10
#
#    max_value
# 0        100
# {'Emissions': 175254750000000.0, 'Cost': 8.0346985, 'Cobenefits': 16969068000.0}
# {'Emissions': 175254750000000.0,
#  'Cost': 8.0346985,
#  'Cobenefits': 16969068000.0}

# %%
import rhodium as rhodium

rhodium_model = rhodium.Model(policy_model)
rhodium_model.parameters = [rhodium.Parameter('elec_renewable_portfolio_standards________maxval'),
                            rhodium.Parameter('elec_renewable_portfolio_standards________maxby'),
                            rhodium.Parameter('elec_renewable_portfolio_standards________start')]
rhodium_model.responses = [rhodium.Response('Emissions', rhodium.Response.MINIMIZE),
                           rhodium.Response('Cost', rhodium.Response.MINIMIZE),
                           rhodium.Response('Cobenefits')]
rhodium_model.levers = [rhodium.IntegerLever('elec_renewable_portfolio_standards________maxval', 0, 100, length=1),
                        rhodium.IntegerLever('elec_renewable_portfolio_standards________maxby', 5, 10, length=1),
                        rhodium.IntegerLever('elec_renewable_portfolio_standards________start', 2025, 2030, length=1)]




output = rhodium.optimize(rhodium_model, "NSGAII", 10)
print("Found", len(output), "optimal policies!")
# Out:
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
#
#    max_value
# 0         69
# {'Emissions': 177817720000000.0, 'Cost': 7.841808, 'Cobenefits': 16901946000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
#
#    max_value
# 0         31
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
#
#    max_value
# 0         82
# {'Emissions': 179436220000000.0, 'Cost': 7.719529, 'Cobenefits': 16877601000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
#
#    max_value
# 0         50
# {'Emissions': 179822530000000.0, 'Cost': 7.688291, 'Cobenefits': 16909493000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030      10
#
#    max_value
# 0          4
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
#
#    max_value
# 0         59
# {'Emissions': 179543200000000.0, 'Cost': 7.711007, 'Cobenefits': 16888321000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
#
#    max_value
# 0         42
# {'Emissions': 180099070000000.0, 'Cost': 7.6673865, 'Cobenefits': 16914214000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
#
#    max_value
# 0         55
# {'Emissions': 179421570000000.0, 'Cost': 7.719766, 'Cobenefits': 16902321000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0         48
# {'Emissions': 180120310000000.0, 'Cost': 7.666229, 'Cobenefits': 16904746000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
#
#    max_value
# 0         47
# {'Emissions': 179811860000000.0, 'Cost': 7.6887064, 'Cobenefits': 16918854000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
#
#    max_value
# 0         26
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       5
#
#    max_value
# 0         29
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
#
#    max_value
# 0         32
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       7
#
#    max_value
# 0         33
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
#
#    max_value
# 0         63
# {'Emissions': 179600580000000.0, 'Cost': 7.7066417, 'Cobenefits': 16891414000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         63
# {'Emissions': 177355190000000.0, 'Cost': 7.8802905, 'Cobenefits': 16963921000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
#
#    max_value
# 0         44
# {'Emissions': 180117490000000.0, 'Cost': 7.665041, 'Cobenefits': 16914427000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
#
#    max_value
# 0         46
# {'Emissions': 180156280000000.0, 'Cost': 7.6632595, 'Cobenefits': 16908268000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         83
# {'Emissions': 179511200000000.0, 'Cost': 7.7140055, 'Cobenefits': 16879654000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         61
# {'Emissions': 177629000000000.0, 'Cost': 7.8590302, 'Cobenefits': 16940240000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
#
#    max_value
# 0         99
# {'Emissions': 178648660000000.0, 'Cost': 7.7804894, 'Cobenefits': 16874055000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0         35
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0         49
# {'Emissions': 180093180000000.0, 'Cost': 7.667951, 'Cobenefits': 16905068000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
#
#    max_value
# 0         79
# {'Emissions': 179189090000000.0, 'Cost': 7.738771, 'Cobenefits': 16855013000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
#
#    max_value
# 0         95
# {'Emissions': 179566120000000.0, 'Cost': 7.7113333, 'Cobenefits': 16872855000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
#
#    max_value
# 0          1
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         99
# {'Emissions': 170572180000000.0, 'Cost': 8.41475, 'Cobenefits': 18579122000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
#
#    max_value
# 0         40
# {'Emissions': 180255670000000.0, 'Cost': 7.654945, 'Cobenefits': 16911307000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
#
#    max_value
# 0         27
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
#
#    max_value
# 0         11
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
#
#    max_value
# 0         12
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       8
#
#    max_value
# 0         69
# {'Emissions': 179281000000000.0, 'Cost': 7.7317038, 'Cobenefits': 16876559000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
#
#    max_value
# 0         55
# {'Emissions': 179678100000000.0, 'Cost': 7.6995444, 'Cobenefits': 16905466000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
#
#    max_value
# 0         62
# {'Emissions': 179630780000000.0, 'Cost': 7.7040286, 'Cobenefits': 16891520000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
#
#    max_value
# 0         64
# {'Emissions': 178301730000000.0, 'Cost': 7.80383, 'Cobenefits': 16912800000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
#
#    max_value
# 0         88
# {'Emissions': 179681900000000.0, 'Cost': 7.70005, 'Cobenefits': 16879200000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         56
# {'Emissions': 180023350000000.0, 'Cost': 7.6743937, 'Cobenefits': 16902481000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
#
#    max_value
# 0         19
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
#
#    max_value
# 0         98
# {'Emissions': 171499130000000.0, 'Cost': 8.333894, 'Cobenefits': 17965386000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         56
# {'Emissions': 180023350000000.0, 'Cost': 7.6743937, 'Cobenefits': 16902481000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
#
#    max_value
# 0         64
# {'Emissions': 177450620000000.0, 'Cost': 7.8700175, 'Cobenefits': 16942692000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         17
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026      10
#
#    max_value
# 0         51
# {'Emissions': 179710810000000.0, 'Cost': 7.6977925, 'Cobenefits': 16916162000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       5
#
#    max_value
# 0         20
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       8
#
#    max_value
# 0         15
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
#
#    max_value
# 0         70
# {'Emissions': 179691480000000.0, 'Cost': 7.700436, 'Cobenefits': 16887414000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
#
#    max_value
# 0         97
# {'Emissions': 173032190000000.0, 'Cost': 8.209447, 'Cobenefits': 17444694000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0         84
# {'Emissions': 179030760000000.0, 'Cost': 7.7522817, 'Cobenefits': 16858508000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
#
#    max_value
# 0         58
# {'Emissions': 179428920000000.0, 'Cost': 7.7203007, 'Cobenefits': 16884907000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
#
#    max_value
# 0         21
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
#
#    max_value
# 0         37
# {'Emissions': 180101400000000.0, 'Cost': 7.666466, 'Cobenefits': 16913814000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
#
#    max_value
# 0        100
# {'Emissions': 176966410000000.0, 'Cost': 7.9083223, 'Cobenefits': 16903335000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
#
#    max_value
# 0         13
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
#
#    max_value
# 0         38
# {'Emissions': 180204870000000.0, 'Cost': 7.6600223, 'Cobenefits': 16914560000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
#
#    max_value
# 0         92
# {'Emissions': 175113800000000.0, 'Cost': 8.054177, 'Cobenefits': 17256880000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
#
#    max_value
# 0         99
# {'Emissions': 173864000000000.0, 'Cost': 8.1517515, 'Cobenefits': 17508962000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
#
#    max_value
# 0         92
# {'Emissions': 178858240000000.0, 'Cost': 7.764663, 'Cobenefits': 16869254000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         10
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
#
#    max_value
# 0          7
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       8
#
#    max_value
# 0         51
# {'Emissions': 180066920000000.0, 'Cost': 7.6703258, 'Cobenefits': 16903253000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         72
# {'Emissions': 175864530000000.0, 'Cost': 7.998502, 'Cobenefits': 17191360000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
#
#    max_value
# 0         78
# {'Emissions': 177140220000000.0, 'Cost': 7.894901, 'Cobenefits': 16951254000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026      10
#
#    max_value
# 0         68
# {'Emissions': 178833550000000.0, 'Cost': 7.7633867, 'Cobenefits': 16907520000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
#
#    max_value
# 0         60
# {'Emissions': 180056640000000.0, 'Cost': 7.671722, 'Cobenefits': 16900641000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       7
#
#    max_value
# 0         55
# {'Emissions': 180077090000000.0, 'Cost': 7.669109, 'Cobenefits': 16901520000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       8
#
#    max_value
# 0         48
# {'Emissions': 180039950000000.0, 'Cost': 7.6719294, 'Cobenefits': 16906934000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
#
#    max_value
# 0          7
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
#
#    max_value
# 0         60
# {'Emissions': 179928360000000.0, 'Cost': 7.6819963, 'Cobenefits': 16891014000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         45
# {'Emissions': 179600550000000.0, 'Cost': 7.7040286, 'Cobenefits': 16925253000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
#
#    max_value
# 0         90
# {'Emissions': 175340260000000.0, 'Cost': 8.027602, 'Cobenefits': 16976801000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
#
#    max_value
# 0         21
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
#
#    max_value
# 0         76
# {'Emissions': 178377780000000.0, 'Cost': 7.801543, 'Cobenefits': 16840080000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
#
#    max_value
# 0         27
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         89
# {'Emissions': 179391690000000.0, 'Cost': 7.7236857, 'Cobenefits': 16872747000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0        100
# {'Emissions': 178211920000000.0, 'Cost': 7.8140435, 'Cobenefits': 16867626000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
#
#    max_value
# 0         65
# {'Emissions': 178115620000000.0, 'Cost': 7.819746, 'Cobenefits': 16899626000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
#
#    max_value
# 0         48
# {'Emissions': 179932470000000.0, 'Cost': 7.6812534, 'Cobenefits': 16909920000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
#
#    max_value
# 0          6
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
#
#    max_value
# 0          9
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
#
#    max_value
# 0          8
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
#
#    max_value
# 0         34
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
#
#    max_value
# 0         71
# {'Emissions': 179515980000000.0, 'Cost': 7.714689, 'Cobenefits': 16868347000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
#
#    max_value
# 0         79
# {'Emissions': 174027210000000.0, 'Cost': 8.13833, 'Cobenefits': 17401629000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
#
#    max_value
# 0         89
# {'Emissions': 177147990000000.0, 'Cost': 7.8957615, 'Cobenefits': 16927118000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026      10
#
#    max_value
# 0         88
# {'Emissions': 177753210000000.0, 'Cost': 7.8454604, 'Cobenefits': 16896051000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
#
#    max_value
# 0         56
# {'Emissions': 178959780000000.0, 'Cost': 7.755904, 'Cobenefits': 16908854000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
#
#    max_value
# 0         86
# {'Emissions': 176775970000000.0, 'Cost': 7.9218035, 'Cobenefits': 16885040000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
#
#    max_value
# 0         18
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
#
#    max_value
# 0         51
# {'Emissions': 179623150000000.0, 'Cost': 7.702722, 'Cobenefits': 16919574000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
#
#    max_value
# 0         78
# {'Emissions': 178948720000000.0, 'Cost': 7.758368, 'Cobenefits': 16852907000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
#
#    max_value
# 0         42
# {'Emissions': 179929700000000.0, 'Cost': 7.6803923, 'Cobenefits': 16920987000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       5
#
#    max_value
# 0          4
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
#
#    max_value
# 0         37
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
#
#    max_value
# 0         39
# {'Emissions': 180258670000000.0, 'Cost': 7.654737, 'Cobenefits': 16910853000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
#
#    max_value
# 0         40
# {'Emissions': 180109840000000.0, 'Cost': 7.665367, 'Cobenefits': 16918106000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030      10
#
#    max_value
# 0         22
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030      10
#
#    max_value
# 0         75
# {'Emissions': 179896600000000.0, 'Cost': 7.6840744, 'Cobenefits': 16890267000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       5
#
#    max_value
# 0         27
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       5
#
#    max_value
# 0         77
# {'Emissions': 173377210000000.0, 'Cost': 8.197064, 'Cobenefits': 17471680000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       5
#
#    max_value
# 0         65
# {'Emissions': 177922850000000.0, 'Cost': 7.8382144, 'Cobenefits': 16932346000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
#
#    max_value
# 0         69
# {'Emissions': 177817720000000.0, 'Cost': 7.841808, 'Cobenefits': 16901946000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
#
#    max_value
# 0         31
# {'Emissions': 180261960000000.0, 'Cost': 7.6545587, 'Cobenefits': 16909894000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
#
#    max_value
# 0         82
# {'Emissions': 179436220000000.0, 'Cost': 7.719529, 'Cobenefits': 16877601000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
#
#    max_value
# 0         50
# {'Emissions': 179822530000000.0, 'Cost': 7.688291, 'Cobenefits': 16909493000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
#
#    max_value
# 0         59
# {'Emissions': 179543200000000.0, 'Cost': 7.711007, 'Cobenefits': 16888321000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
#
#    max_value
# 0         42
# {'Emissions': 180099070000000.0, 'Cost': 7.6673865, 'Cobenefits': 16914214000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
#
#    max_value
# 0         55
# {'Emissions': 179421570000000.0, 'Cost': 7.719766, 'Cobenefits': 16902321000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
#
#    max_value
# 0         47
# {'Emissions': 179811860000000.0, 'Cost': 7.6887064, 'Cobenefits': 16918854000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         63
# {'Emissions': 177355190000000.0, 'Cost': 7.8802905, 'Cobenefits': 16963921000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
#
#    max_value
# 0         44
# {'Emissions': 180117490000000.0, 'Cost': 7.665041, 'Cobenefits': 16914427000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
#
#    max_value
# 0         46
# {'Emissions': 180156280000000.0, 'Cost': 7.6632595, 'Cobenefits': 16908268000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         83
# {'Emissions': 179511200000000.0, 'Cost': 7.7140055, 'Cobenefits': 16879654000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         61
# {'Emissions': 177629000000000.0, 'Cost': 7.8590302, 'Cobenefits': 16940240000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
#
#    max_value
# 0         99
# {'Emissions': 178648660000000.0, 'Cost': 7.7804894, 'Cobenefits': 16874055000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0         49
# {'Emissions': 180093180000000.0, 'Cost': 7.667951, 'Cobenefits': 16905068000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
#
#    max_value
# 0         79
# {'Emissions': 179189090000000.0, 'Cost': 7.738771, 'Cobenefits': 16855013000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       5
#
#    max_value
# 0         99
# {'Emissions': 170572180000000.0, 'Cost': 8.41475, 'Cobenefits': 18579122000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
#
#    max_value
# 0         40
# {'Emissions': 180255670000000.0, 'Cost': 7.654945, 'Cobenefits': 16911307000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       8
#
#    max_value
# 0         69
# {'Emissions': 179281000000000.0, 'Cost': 7.7317038, 'Cobenefits': 16876559000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
#
#    max_value
# 0         55
# {'Emissions': 179678100000000.0, 'Cost': 7.6995444, 'Cobenefits': 16905466000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
#
#    max_value
# 0         64
# {'Emissions': 178301730000000.0, 'Cost': 7.80383, 'Cobenefits': 16912800000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
#
#    max_value
# 0         56
# {'Emissions': 180023350000000.0, 'Cost': 7.6743937, 'Cobenefits': 16902481000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
#
#    max_value
# 0         98
# {'Emissions': 171499130000000.0, 'Cost': 8.333894, 'Cobenefits': 17965386000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
#
#    max_value
# 0         64
# {'Emissions': 177450620000000.0, 'Cost': 7.8700175, 'Cobenefits': 16942692000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026      10
#
#    max_value
# 0         51
# {'Emissions': 179710810000000.0, 'Cost': 7.6977925, 'Cobenefits': 16916162000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
#
#    max_value
# 0         97
# {'Emissions': 173032190000000.0, 'Cost': 8.209447, 'Cobenefits': 17444694000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
#
#    max_value
# 0         84

# %%
rhodium.parallel_coordinates(rhodium_model, output)
rhodium.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\pkane\Desktop\EPS Optimizer\Optimizer Notebook.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pkane/Desktop/EPS%20Optimizer/Optimizer%20Notebook.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> rhodium.parallel_coordinates(rhodium_model, output)
#       <a href='vscode-notebook-cell:/c%3A/Users/pkane/Desktop/EPS%20Optimizer/Optimizer%20Notebook.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> rhodium.plt.show()
#
# File c:\Users\pkane\.conda\envs\prj-lmr-scistack\lib\site-packages\rhodium\plot.py:860, in parallel_coordinates(model, data, c, cols, ax, colors, use_columns, xticks, colormap, target, brush, zorder, **kwds)
#     858     cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap, spacing='proportional', norm=mpl.colors.Normalize(vmin=class_min, vmax=class_max), format='%.2f')
#     859     cb.set_label(c)
# --> 860     cb.set_clim(class_min, class_max)
#     862 mpl.rcParams["axes.facecolor"] = orig_facecolor
#     864 return fig
#
# AttributeError: 'Colorbar' object has no attribute 'set_clim'
