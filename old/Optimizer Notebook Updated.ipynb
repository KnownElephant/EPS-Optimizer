# %%
from __future__ import (division, unicode_literals, absolute_import,
                        print_function)

from ema_workbench import (Model, ScalarOutcome, TimeSeriesOutcome, perform_experiments,
                           RealParameter, CategoricalParameter, IntegerParameter, ema_logging)

from ema_workbench.connectors.vensim import VensimModel

import pandas as pd
import math
import numpy as np
# Out:
# c:\Users\pkane\.conda\envs\prj-lmr-scistack\lib\site-packages\ema_workbench\em_framework\evaluators.py:21: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn(
# c:\Users\pkane\.conda\envs\prj-lmr-scistack\lib\site-packages\ema_workbench\connectors\__init__.py:27: ImportWarning: netlogo connector not available
#   warnings.warn("netlogo connector not available", ImportWarning)

# %%
def row_writer(data, policy_name, start, max_by, max_value, interpolate=True, sub_1="", sub_2="", sub_3=""):
    target_row = (data['Policy']==policy_name) & (data['Subscript 1']==sub_1) & (data['Subscript 2']==sub_2) & (data['Subscript 3']==sub_3)

    data.loc[target_row, "2020":"2050"]=(max_value/100)*np.concatenate((np.zeros(start-2020),[i/(max_by) for i in list(range(0, min(max_by, 2050-start)))],np.ones(max(31-start-max_by+2020, 0))))

# %%
def policy_writer(**kwargs):
    policies = pd.DataFrame(columns=['policy', 'sub_1', 'sub_2', 'sub_3', 'start', 'max_by', 'max_value'])
    for key, value in kwargs.items():
        ids=key.split('__')
        if(((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])).any()==False):
            policies.loc[len(policies.index)] = [ids[0], ids[1], ids[2], ids[3], 0, 0, 0]
        
        
        if(ids[-1]=='start'):
            policies.loc[((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])), 'start']=value
        elif(ids[-1]=='maxby'):
            policies.loc[((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])), 'max_by']=value
        elif(ids[-1]=='maxval'):
            policies.loc[((policies['policy']==ids[0]) & 
            (policies['sub_1']==ids[1]) & 
            (policies['sub_2']==ids[2]) &
            (policies['sub_3']==ids[3])), 'max_value']=value
    print(policies)
    read_data = pd.read_csv('C:\\Users\\pkane\\Documents\\eps-louisiana-3.2.1\\eps-louisiana-3.2.1\\InputData\\plcy-schd\\FoPITY\\FoPITY-1-default.csv',
        keep_default_na=False)
    for index, policy in policies.iterrows():
        row_writer(data=read_data, 
                   policy_name=policy['policy'].replace('_', ' '), 
                   start=policy['start'],
                   max_by=policy['max_by'],
                   max_value=policy['max_value'],
                   sub_1=policy['sub_1'].replace('_', ' '),
                   sub_2=policy['sub_2'].replace('_', ' '),
                   sub_3=policy['sub_3'].replace('_', ' ')
                   )
    read_data.to_csv('FoPITY-1.csv',
                     index=False)
    read_data.to_csv('C:\\Users\\pkane\\Documents\\eps-louisiana-3.2.1\\eps-louisiana-3.2.1\\InputData\\plcy-schd\\FoPITY\\FoPITY-1.csv',
                     index=False)
    
    
def run_inner_model():
    wd = 'C:\\Users\\pkane\\Documents\\eps-louisiana-3.2.1\\eps-louisiana-3.2.1'
    innerModel = VensimModel("simpleModel", wd=wd,
                              model_file='EPS CAP.vpmx')
    innerModel.uncertainties = [RealParameter('xdata', 0, 1)]

    innerModel.outcomes = [TimeSeriesOutcome('Total CO2e Emissions'),
                           TimeSeriesOutcome('BAU Total CO2e Emissions'),
                           TimeSeriesOutcome('Output Social Benefits from Emissions Reduction'),
                           TimeSeriesOutcome('Total Change In CapEx and OpEx'),
                           TimeSeriesOutcome('Output Change in Domestic Jobs'),
                           TimeSeriesOutcome('Output Change in GDP')
                           ]

    inner_results = perform_experiments(innerModel, 1)

    inner_experiments, inner_outcomes = inner_results

    actual_outcomes = {'Emissions':np.mean(inner_outcomes['Total CO2e Emissions'][0][0:15]),
                      'Cost': np.mean(inner_outcomes['Output Social Benefits from Emissions Reduction'][0][0:15]),
                      'Cobenefits':np.mean(inner_outcomes['Total Change In CapEx and OpEx'][0][0:15])}
    print(actual_outcomes)

    return actual_outcomes

def policy_model(**policies):
    print("Running")
    policy_writer(**policies)
    return run_inner_model()

# %%
policy_model(elec_renewable_portfolio_standards________maxval=100, 
elec_renewable_portfolio_standards________start=2025,
elec_renewable_portfolio_standards________maxby=10)
# Out:
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025      10
#
#    max_value
# 0        100
# {'Emissions': 175254750000000.0, 'Cost': 8.0346985, 'Cobenefits': 16969068000.0}
# {'Emissions': 175254750000000.0,
#  'Cost': 8.0346985,
#  'Cobenefits': 16969068000.0}

# %%
import rhodium as rhodium

rhodium_model = rhodium.Model(policy_model)
rhodium_model.parameters = [rhodium.Parameter('elec_renewable_portfolio_standards________maxval'),
                            rhodium.Parameter('elec_renewable_portfolio_standards________maxby'),
                            rhodium.Parameter('elec_renewable_portfolio_standards________start'),
                            rhodium.Parameter('hydgn_shift_production_pathways________start'),
                            rhodium.Parameter('hydgn_shift_production_pathways________maxby'),
                            rhodium.Parameter('hydgn_shift_production_pathways________maxval')]
rhodium_model.responses = [rhodium.Response('Emissions', rhodium.Response.MINIMIZE),
                           rhodium.Response('Cost', rhodium.Response.MINIMIZE),
                           rhodium.Response('Cobenefits')]
rhodium_model.levers = [rhodium.IntegerLever('elec_renewable_portfolio_standards________maxval', 0, 100, length=1),
                        rhodium.IntegerLever('elec_renewable_portfolio_standards________maxby', 5, 10, length=1),
                        rhodium.IntegerLever('elec_renewable_portfolio_standards________start', 2025, 2030, length=1),
                        rhodium.IntegerLever('hydgn_shift_production_pathways________maxval', 0, 100, length=1),
                        rhodium.IntegerLever('hydgn_shift_production_pathways________maxby', 5, 10, length=1),
                        rhodium.IntegerLever('hydgn_shift_production_pathways________start', 2025, 2030, length=1)]




output = rhodium.optimize(rhodium_model, "NSGAII", 10)
print("Found", len(output), "optimal policies!")
# Out:
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0         42
# 1         28
# {'Emissions': 183053300000000.0, 'Cost': 7.398242, 'Cobenefits': 13285413000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025      10
# 1     hydgn_shift_production_pathways                     2030       9
#
#    max_value
# 0         78
# 1         76
# {'Emissions': 180382720000000.0, 'Cost': 7.5991507, 'Cobenefits': 13636135000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
# 1     hydgn_shift_production_pathways                     2028       8
#
#    max_value
# 0         42
# 1         35
# {'Emissions': 182773640000000.0, 'Cost': 7.417751, 'Cobenefits': 13734107000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2026       9
#
#    max_value
# 0          5
# 1         76
# {'Emissions': 180137970000000.0, 'Cost': 7.628665, 'Cobenefits': 17353920000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         89
# 1         48
# {'Emissions': 181004750000000.0, 'Cost': 7.5586176, 'Cobenefits': 13650614000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         15
# 1         91
# {'Emissions': 179798540000000.0, 'Cost': 7.660498, 'Cobenefits': 17801600000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         67
# 1         42
# {'Emissions': 180959290000000.0, 'Cost': 7.5645275, 'Cobenefits': 14593176000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0         50
# 1          0
# {'Emissions': 183912610000000.0, 'Cost': 7.329916, 'Cobenefits': 12195254000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         66
# 1         81
# {'Emissions': 179887570000000.0, 'Cost': 7.641909, 'Cobenefits': 14719733000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2030       8
#
#    max_value
# 0         85
# 1         10
# {'Emissions': 182254070000000.0, 'Cost': 7.4583426, 'Cobenefits': 12370801000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2030       8
#
#    max_value
# 0         39
# 1         74
# {'Emissions': 182513910000000.0, 'Cost': 7.4376454, 'Cobenefits': 13821972000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         95
# 1          0
# {'Emissions': 179076980000000.0, 'Cost': 7.7094326, 'Cobenefits': 12674267000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       7
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         19
# 1         50
# {'Emissions': 182827700000000.0, 'Cost': 7.413683, 'Cobenefits': 13628189000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2026       5
#
#    max_value
# 0         25
# 1         22
# {'Emissions': 182403170000000.0, 'Cost': 7.4511566, 'Cobenefits': 14361654000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         36
# 1          1
# {'Emissions': 183977420000000.0, 'Cost': 7.325076, 'Cobenefits': 12282986000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         17
# 1         96
# {'Emissions': 177741060000000.0, 'Cost': 7.822833, 'Cobenefits': 21107227000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
# 1     hydgn_shift_production_pathways                     2026       7
#
#    max_value
# 0          0
# 1         87
# {'Emissions': 178407500000000.0, 'Cost': 7.773601, 'Cobenefits': 19915200000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
# 1     hydgn_shift_production_pathways                     2026       8
#
#    max_value
# 0         44
# 1          4
# {'Emissions': 183237570000000.0, 'Cost': 7.37998, 'Cobenefits': 12501732000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2030       7
#
#    max_value
# 0         28
# 1         47
# {'Emissions': 183069740000000.0, 'Cost': 7.3959255, 'Cobenefits': 13314293000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2025       8
#
#    max_value
# 0         68
# 1         79
# {'Emissions': 176586900000000.0, 'Cost': 7.9212394, 'Cobenefits': 19493493000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2025       9
#
#    max_value
# 0         98
# 1         59
# {'Emissions': 174638840000000.0, 'Cost': 8.058573, 'Cobenefits': 17408373000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         78
# 1         65
# {'Emissions': 179302740000000.0, 'Cost': 7.6855593, 'Cobenefits': 14632000000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2028       7
#
#    max_value
# 0         27
# 1         96
# {'Emissions': 180104790000000.0, 'Cost': 7.628874, 'Cobenefits': 17589279000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
# 1     hydgn_shift_production_pathways                     2025       6
#
#    max_value
# 0         52
# 1         72
# {'Emissions': 176896310000000.0, 'Cost': 7.895049, 'Cobenefits': 19939172000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
# 1     hydgn_shift_production_pathways                     2026       5
#
#    max_value
# 0         12
# 1         53
# {'Emissions': 179992990000000.0, 'Cost': 7.649125, 'Cobenefits': 17550184000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       5
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         75
# 1         32
# {'Emissions': 175814020000000.0, 'Cost': 7.97635, 'Cobenefits': 15334960000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         10
# 1         15
# {'Emissions': 183332740000000.0, 'Cost': 7.3769813, 'Cobenefits': 13075679000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       5
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         71
# 1         88
# {'Emissions': 174867460000000.0, 'Cost': 8.051505, 'Cobenefits': 20365680000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         50
# 1         42
# {'Emissions': 181830480000000.0, 'Cost': 7.4940343, 'Cobenefits': 14701760000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         83
# 1          6
# {'Emissions': 182660580000000.0, 'Cost': 7.427193, 'Cobenefits': 12331041000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030      10
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0         78
# 1         80
# {'Emissions': 180778930000000.0, 'Cost': 7.5753655, 'Cobenefits': 15970080000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         74
# 1          3
# {'Emissions': 182389540000000.0, 'Cost': 7.447682, 'Cobenefits': 12253840000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
# 1     hydgn_shift_production_pathways                     2030       7
#
#    max_value
# 0         57
# 1         20
# {'Emissions': 183063050000000.0, 'Cost': 7.3956285, 'Cobenefits': 12656535000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
# 1     hydgn_shift_production_pathways                     2025       8
#
#    max_value
# 0         86
# 1         96
# {'Emissions': 172579740000000.0, 'Cost': 8.229816, 'Cobenefits': 21326133000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         30
# 1         37
# {'Emissions': 181636730000000.0, 'Cost': 7.5106325, 'Cobenefits': 15368239000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
# 1     hydgn_shift_production_pathways                     2030       5
#
#    max_value
# 0         15
# 1         15
# {'Emissions': 183600070000000.0, 'Cost': 7.3542356, 'Cobenefits': 12687894000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
# 1     hydgn_shift_production_pathways                     2026       6
#
#    max_value
# 0          0
# 1         77
# {'Emissions': 178622220000000.0, 'Cost': 7.755458, 'Cobenefits': 19611654000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         52
# 1         87
# {'Emissions': 181680560000000.0, 'Cost': 7.5054955, 'Cobenefits': 14794774000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2028       8
#
#    max_value
# 0         47
# 1         28
# {'Emissions': 182855580000000.0, 'Cost': 7.4123464, 'Cobenefits': 13422854000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2027       6
#
#    max_value
# 0         72
# 1         81
# {'Emissions': 174384600000000.0, 'Cost': 8.073834, 'Cobenefits': 19074880000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
# 1     hydgn_shift_production_pathways                     2025      10
#
#    max_value
# 0         32
# 1         72
# {'Emissions': 180022870000000.0, 'Cost': 7.642146, 'Cobenefits': 17475465000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         55
# 1         64
# {'Emissions': 181433360000000.0, 'Cost': 7.522006, 'Cobenefits': 14111227000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         74
# 1         74
# {'Emissions': 180798610000000.0, 'Cost': 7.574653, 'Cobenefits': 15070879000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       8
# 1     hydgn_shift_production_pathways                     2026       8
#
#    max_value
# 0         27
# 1         76
# {'Emissions': 179600350000000.0, 'Cost': 7.6770372, 'Cobenefits': 18070800000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
# 1     hydgn_shift_production_pathways                     2030       5
#
#    max_value
# 0         14
# 1         56
# {'Emissions': 182409060000000.0, 'Cost': 7.446138, 'Cobenefits': 14250933000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
# 1     hydgn_shift_production_pathways                     2027       6
#
#    max_value
# 0         14
# 1         15
# {'Emissions': 183143300000000.0, 'Cost': 7.391531, 'Cobenefits': 13339388000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0         74
# 1         45
# {'Emissions': 180856560000000.0, 'Cost': 7.568833, 'Cobenefits': 14104373000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2030       7
#
#    max_value
# 0         23
# 1         64
# {'Emissions': 182708980000000.0, 'Cost': 7.4233627, 'Cobenefits': 13796934000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2028      10
#
#    max_value
# 0          0
# 1         56
# {'Emissions': 182435930000000.0, 'Cost': 7.445396, 'Cobenefits': 14168293000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
# 1     hydgn_shift_production_pathways                     2030       8
#
#    max_value
# 0        100
# 1         81
# {'Emissions': 177000220000000.0, 'Cost': 7.873937, 'Cobenefits': 14221118000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2025       9
#
#    max_value
# 0         97
# 1         58
# {'Emissions': 178883090000000.0, 'Cost': 7.7311387, 'Cobenefits': 16833308000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026      10
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         68
# 1         79
# {'Emissions': 178859650000000.0, 'Cost': 7.7308717, 'Cobenefits': 16992106000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2027       6
#
#    max_value
# 0         39
# 1          7
# {'Emissions': 183475130000000.0, 'Cost': 7.3648067, 'Cobenefits': 12737789000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         72
# 1         69
# {'Emissions': 181635400000000.0, 'Cost': 7.5082273, 'Cobenefits': 14444293000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2028       5
#
#    max_value
# 0        100
# 1          7
# {'Emissions': 179919940000000.0, 'Cost': 7.6425033, 'Cobenefits': 12918932000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         89
# 1         72
# {'Emissions': 179940670000000.0, 'Cost': 7.6441956, 'Cobenefits': 16792638000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2025      10
#
#    max_value
# 0         75
# 1         67
# {'Emissions': 177920510000000.0, 'Cost': 7.8044825, 'Cobenefits': 17022428000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2026       5
#
#    max_value
# 0          3
# 1         66
# {'Emissions': 179055930000000.0, 'Cost': 7.7237453, 'Cobenefits': 18977868000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2027       6
#
#    max_value
# 0         89
# 1         60
# {'Emissions': 178925620000000.0, 'Cost': 7.721726, 'Cobenefits': 16929412000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         42
# 1         84
# {'Emissions': 181650660000000.0, 'Cost': 7.506179, 'Cobenefits': 15074321000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
# 1     hydgn_shift_production_pathways                     2030      10
#
#    max_value
# 0         15
# 1         85
# {'Emissions': 182799330000000.0, 'Cost': 7.4167705, 'Cobenefits': 13661868000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
# 1     hydgn_shift_production_pathways                     2026       6
#
#    max_value
# 0         47
# 1          4
# {'Emissions': 183548360000000.0, 'Cost': 7.357561, 'Cobenefits': 12566720000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         80
# 1         89
# {'Emissions': 179243580000000.0, 'Cost': 7.6989217, 'Cobenefits': 18049468000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
# 1     hydgn_shift_production_pathways                     2027       9
#
#    max_value
# 0          8
# 1         66
# {'Emissions': 181310180000000.0, 'Cost': 7.535428, 'Cobenefits': 15685759000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         57
# 1         82
# {'Emissions': 178768700000000.0, 'Cost': 7.7374043, 'Cobenefits': 17206694000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2028       5
#
#    max_value
# 0         71
# 1         41
# {'Emissions': 180390190000000.0, 'Cost': 7.606722, 'Cobenefits': 15047760000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2026       7
#
#    max_value
# 0         65
# 1          8
# {'Emissions': 182852750000000.0, 'Cost': 7.412376, 'Cobenefits': 12831440000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         73
# 1         18
# {'Emissions': 181232000000000.0, 'Cost': 7.53801, 'Cobenefits': 13189546000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2029       5
#
#    max_value
# 0         18
# 1         67
# {'Emissions': 181201700000000.0, 'Cost': 7.5420485, 'Cobenefits': 16017095000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
# 1     hydgn_shift_production_pathways                     2027      10
#
#    max_value
# 0          2
# 1         50
# {'Emissions': 182184980000000.0, 'Cost': 7.4668646, 'Cobenefits': 14514454000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025      10
# 1     hydgn_shift_production_pathways                     2028      10
#
#    max_value
# 0         20
# 1         36
# {'Emissions': 183020220000000.0, 'Cost': 7.399222, 'Cobenefits': 13463760000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2027       8
#
#    max_value
# 0         73
# 1         60
# {'Emissions': 180593140000000.0, 'Cost': 7.591429, 'Cobenefits': 15757493000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         50
# 1         83
# {'Emissions': 179170650000000.0, 'Cost': 7.6993375, 'Cobenefits': 17664027000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0        100
# 1         59
# {'Emissions': 175127800000000.0, 'Cost': 8.021723, 'Cobenefits': 14588640000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
# 1     hydgn_shift_production_pathways                     2030       7
#
#    max_value
# 0         75
# 1         77
# {'Emissions': 181054230000000.0, 'Cost': 7.553392, 'Cobenefits': 14151414000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
# 1     hydgn_shift_production_pathways                     2025       8
#
#    max_value
# 0         92
# 1         55
# {'Emissions': 177907580000000.0, 'Cost': 7.8059974, 'Cobenefits': 17102881000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         26
# 1         69
# {'Emissions': 180758310000000.0, 'Cost': 7.577592, 'Cobenefits': 16611466000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0         66
# 1         21
# {'Emissions': 181923340000000.0, 'Cost': 7.4842353, 'Cobenefits': 12976187000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         69
# 1         71
# {'Emissions': 181199070000000.0, 'Cost': 7.541811, 'Cobenefits': 14234879000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         30
# 1         56
# {'Emissions': 182347970000000.0, 'Cost': 7.4515424, 'Cobenefits': 14284373000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0         59
# 1         25
# {'Emissions': 182724770000000.0, 'Cost': 7.4246693, 'Cobenefits': 13148773000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2029      10
#
#    max_value
# 0         88
# 1         13
# {'Emissions': 182673180000000.0, 'Cost': 7.4264507, 'Cobenefits': 12485787000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         20
# 1         14
# {'Emissions': 183705830000000.0, 'Cost': 7.3453875, 'Cobenefits': 12580481000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         28
# 1          2
# {'Emissions': 183996130000000.0, 'Cost': 7.3238883, 'Cobenefits': 12252613000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0          9
# 1         58
# {'Emissions': 182206390000000.0, 'Cost': 7.464073, 'Cobenefits': 14490054000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
# 1     hydgn_shift_production_pathways                     2025       9
#
#    max_value
# 0         69
# 1         93
# {'Emissions': 176374760000000.0, 'Cost': 7.9333243, 'Cobenefits': 20039948000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
# 1     hydgn_shift_production_pathways                     2029      10
#
#    max_value
# 0         51
# 1          8
# {'Emissions': 183397130000000.0, 'Cost': 7.369914, 'Cobenefits': 12392560000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
# 1     hydgn_shift_production_pathways                     2030       5
#
#    max_value
# 0         71
# 1         24
# {'Emissions': 181792040000000.0, 'Cost': 7.4950438, 'Cobenefits': 12917015000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2028       7
#
#    max_value
# 0         51
# 1         92
# {'Emissions': 179158020000000.0, 'Cost': 7.699842, 'Cobenefits': 17359895000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         16
# 1         25
# {'Emissions': 182414060000000.0, 'Cost': 7.4491673, 'Cobenefits': 14322960000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         50
# 1         58
# {'Emissions': 180812970000000.0, 'Cost': 7.568387, 'Cobenefits': 14389547000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
# 1     hydgn_shift_production_pathways                     2027       7
#
#    max_value
# 0         59
# 1         27
# {'Emissions': 181110160000000.0, 'Cost': 7.549116, 'Cobenefits': 13966933000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         13
# 1         11
# {'Emissions': 183336940000000.0, 'Cost': 7.3757634, 'Cobenefits': 13134400000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0          4
# 1         97
# {'Emissions': 180608460000000.0, 'Cost': 7.5882816, 'Cobenefits': 16913066000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
# 1     hydgn_shift_production_pathways                     2025       5
#
#    max_value
# 0         18
# 1          3
# {'Emissions': 183813000000000.0, 'Cost': 7.338676, 'Cobenefits': 12527201000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2026       6
#
#    max_value
# 0         54
# 1         52
# {'Emissions': 179602310000000.0, 'Cost': 7.6745424, 'Cobenefits': 17043228000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         55
# 1         27
# {'Emissions': 182243620000000.0, 'Cost': 7.4615784, 'Cobenefits': 13759228000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       7
# 1     hydgn_shift_production_pathways                     2029       5
#
#    max_value
# 0          0
# 1         50
# {'Emissions': 181920200000000.0, 'Cost': 7.4857197, 'Cobenefits': 14906107000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0          5
# 1         33
# {'Emissions': 183278540000000.0, 'Cost': 7.378882, 'Cobenefits': 13122588000.0}
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         46
# 1         97
# {'Emissions': 181099680000000.0, 'Cost': 7.5514617, 'Cobenefits': 15595918000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0         42
# 1         28
# {'Emissions': 183053300000000.0, 'Cost': 7.398242, 'Cobenefits': 13285413000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025      10
# 1     hydgn_shift_production_pathways                     2030       9
#
#    max_value
# 0         78
# 1         76
# {'Emissions': 180382720000000.0, 'Cost': 7.5991507, 'Cobenefits': 13636135000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
# 1     hydgn_shift_production_pathways                     2028       8
#
#    max_value
# 0         42
# 1         35
# {'Emissions': 182773640000000.0, 'Cost': 7.417751, 'Cobenefits': 13734107000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2026       9
#
#    max_value
# 0          5
# 1         76
# {'Emissions': 180137970000000.0, 'Cost': 7.628665, 'Cobenefits': 17353920000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         89
# 1         48
# {'Emissions': 181004750000000.0, 'Cost': 7.5586176, 'Cobenefits': 13650614000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         15
# 1         91
# {'Emissions': 179798540000000.0, 'Cost': 7.660498, 'Cobenefits': 17801600000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         67
# 1         42
# {'Emissions': 180959290000000.0, 'Cost': 7.5645275, 'Cobenefits': 14593176000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0         50
# 1          0
# {'Emissions': 183912610000000.0, 'Cost': 7.329916, 'Cobenefits': 12195254000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         66
# 1         81
# {'Emissions': 179887570000000.0, 'Cost': 7.641909, 'Cobenefits': 14719733000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2030       8
#
#    max_value
# 0         85
# 1         10
# {'Emissions': 182254070000000.0, 'Cost': 7.4583426, 'Cobenefits': 12370801000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2030       8
#
#    max_value
# 0         39
# 1         74
# {'Emissions': 182513910000000.0, 'Cost': 7.4376454, 'Cobenefits': 13821972000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         95
# 1          0
# {'Emissions': 179076980000000.0, 'Cost': 7.7094326, 'Cobenefits': 12674267000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       7
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         19
# 1         50
# {'Emissions': 182827700000000.0, 'Cost': 7.413683, 'Cobenefits': 13628189000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         36
# 1          1
# {'Emissions': 183977420000000.0, 'Cost': 7.325076, 'Cobenefits': 12282986000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         17
# 1         96
# {'Emissions': 177741060000000.0, 'Cost': 7.822833, 'Cobenefits': 21107227000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
# 1     hydgn_shift_production_pathways                     2026       7
#
#    max_value
# 0          0
# 1         87
# {'Emissions': 178407500000000.0, 'Cost': 7.773601, 'Cobenefits': 19915200000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
# 1     hydgn_shift_production_pathways                     2026       8
#
#    max_value
# 0         44
# 1          4
# {'Emissions': 183237570000000.0, 'Cost': 7.37998, 'Cobenefits': 12501732000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2025       8
#
#    max_value
# 0         68
# 1         79
# {'Emissions': 176586900000000.0, 'Cost': 7.9212394, 'Cobenefits': 19493493000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2025       9
#
#    max_value
# 0         98
# 1         59
# {'Emissions': 174638840000000.0, 'Cost': 8.058573, 'Cobenefits': 17408373000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         78
# 1         65
# {'Emissions': 179302740000000.0, 'Cost': 7.6855593, 'Cobenefits': 14632000000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2028       7
#
#    max_value
# 0         27
# 1         96
# {'Emissions': 180104790000000.0, 'Cost': 7.628874, 'Cobenefits': 17589279000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
# 1     hydgn_shift_production_pathways                     2025       6
#
#    max_value
# 0         52
# 1         72
# {'Emissions': 176896310000000.0, 'Cost': 7.895049, 'Cobenefits': 19939172000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       5
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         75
# 1         32
# {'Emissions': 175814020000000.0, 'Cost': 7.97635, 'Cobenefits': 15334960000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         10
# 1         15
# {'Emissions': 183332740000000.0, 'Cost': 7.3769813, 'Cobenefits': 13075679000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       5
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         71
# 1         88
# {'Emissions': 174867460000000.0, 'Cost': 8.051505, 'Cobenefits': 20365680000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       7
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         50
# 1         42
# {'Emissions': 181830480000000.0, 'Cost': 7.4940343, 'Cobenefits': 14701760000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         83
# 1          6
# {'Emissions': 182660580000000.0, 'Cost': 7.427193, 'Cobenefits': 12331041000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030      10
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0         78
# 1         80
# {'Emissions': 180778930000000.0, 'Cost': 7.5753655, 'Cobenefits': 15970080000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         74
# 1          3
# {'Emissions': 182389540000000.0, 'Cost': 7.447682, 'Cobenefits': 12253840000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
# 1     hydgn_shift_production_pathways                     2030       7
#
#    max_value
# 0         57
# 1         20
# {'Emissions': 183063050000000.0, 'Cost': 7.3956285, 'Cobenefits': 12656535000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       6
# 1     hydgn_shift_production_pathways                     2025       8
#
#    max_value
# 0         86
# 1         96
# {'Emissions': 172579740000000.0, 'Cost': 8.229816, 'Cobenefits': 21326133000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       9
# 1     hydgn_shift_production_pathways                     2030       5
#
#    max_value
# 0         15
# 1         15
# {'Emissions': 183600070000000.0, 'Cost': 7.3542356, 'Cobenefits': 12687894000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
# 1     hydgn_shift_production_pathways                     2026       6
#
#    max_value
# 0          0
# 1         77
# {'Emissions': 178622220000000.0, 'Cost': 7.755458, 'Cobenefits': 19611654000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         52
# 1         87
# ...
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2028      10
#
#    max_value
# 0          0
# 1         56
# {'Emissions': 182435930000000.0, 'Cost': 7.445396, 'Cobenefits': 14168293000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
# 1     hydgn_shift_production_pathways                     2030       8
#
#    max_value
# 0        100
# 1         81
# {'Emissions': 177000220000000.0, 'Cost': 7.873937, 'Cobenefits': 14221118000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026      10
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         68
# 1         79
# {'Emissions': 178859650000000.0, 'Cost': 7.7308717, 'Cobenefits': 16992106000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       6
# 1     hydgn_shift_production_pathways                     2027       6
#
#    max_value
# 0         39
# 1          7
# {'Emissions': 183475130000000.0, 'Cost': 7.3648067, 'Cobenefits': 12737789000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       6
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         72
# 1         69
# {'Emissions': 181635400000000.0, 'Cost': 7.5082273, 'Cobenefits': 14444293000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2025      10
#
#    max_value
# 0         75
# 1         67
# {'Emissions': 177920510000000.0, 'Cost': 7.8044825, 'Cobenefits': 17022428000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2027       6
#
#    max_value
# 0         89
# 1         60
# {'Emissions': 178925620000000.0, 'Cost': 7.721726, 'Cobenefits': 16929412000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         42
# 1         84
# {'Emissions': 181650660000000.0, 'Cost': 7.506179, 'Cobenefits': 15074321000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
# 1     hydgn_shift_production_pathways                     2030      10
#
#    max_value
# 0         15
# 1         85
# {'Emissions': 182799330000000.0, 'Cost': 7.4167705, 'Cobenefits': 13661868000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027      10
# 1     hydgn_shift_production_pathways                     2026       6
#
#    max_value
# 0         47
# 1          4
# {'Emissions': 183548360000000.0, 'Cost': 7.357561, 'Cobenefits': 12566720000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         80
# 1         89
# {'Emissions': 179243580000000.0, 'Cost': 7.6989217, 'Cobenefits': 18049468000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       7
# 1     hydgn_shift_production_pathways                     2027       9
#
#    max_value
# 0          8
# 1         66
# {'Emissions': 181310180000000.0, 'Cost': 7.535428, 'Cobenefits': 15685759000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
# 1     hydgn_shift_production_pathways                     2026      10
#
#    max_value
# 0         57
# 1         82
# {'Emissions': 178768700000000.0, 'Cost': 7.7374043, 'Cobenefits': 17206694000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       6
# 1     hydgn_shift_production_pathways                     2026       7
#
#    max_value
# 0         65
# 1          8
# {'Emissions': 182852750000000.0, 'Cost': 7.412376, 'Cobenefits': 12831440000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         73
# 1         18
# {'Emissions': 181232000000000.0, 'Cost': 7.53801, 'Cobenefits': 13189546000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       8
# 1     hydgn_shift_production_pathways                     2027      10
#
#    max_value
# 0          2
# 1         50
# {'Emissions': 182184980000000.0, 'Cost': 7.4668646, 'Cobenefits': 14514454000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025      10
# 1     hydgn_shift_production_pathways                     2028      10
#
#    max_value
# 0         20
# 1         36
# {'Emissions': 183020220000000.0, 'Cost': 7.399222, 'Cobenefits': 13463760000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2027       8
#
#    max_value
# 0         73
# 1         60
# {'Emissions': 180593140000000.0, 'Cost': 7.591429, 'Cobenefits': 15757493000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         50
# 1         83
# {'Emissions': 179170650000000.0, 'Cost': 7.6993375, 'Cobenefits': 17664027000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0        100
# 1         59
# {'Emissions': 175127800000000.0, 'Cost': 8.021723, 'Cobenefits': 14588640000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       7
# 1     hydgn_shift_production_pathways                     2030       7
#
#    max_value
# 0         75
# 1         77
# {'Emissions': 181054230000000.0, 'Cost': 7.553392, 'Cobenefits': 14151414000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
# 1     hydgn_shift_production_pathways                     2025       8
#
#    max_value
# 0         92
# 1         55
# {'Emissions': 177907580000000.0, 'Cost': 7.8059974, 'Cobenefits': 17102881000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         26
# 1         69
# {'Emissions': 180758310000000.0, 'Cost': 7.577592, 'Cobenefits': 16611466000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0         66
# 1         21
# {'Emissions': 181923340000000.0, 'Cost': 7.4842353, 'Cobenefits': 12976187000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       9
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         69
# 1         71
# {'Emissions': 181199070000000.0, 'Cost': 7.541811, 'Cobenefits': 14234879000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         30
# 1         56
# {'Emissions': 182347970000000.0, 'Cost': 7.4515424, 'Cobenefits': 14284373000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028      10
# 1     hydgn_shift_production_pathways                     2029      10
#
#    max_value
# 0         88
# 1         13
# {'Emissions': 182673180000000.0, 'Cost': 7.4264507, 'Cobenefits': 12485787000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
# 1     hydgn_shift_production_pathways                     2030       6
#
#    max_value
# 0         20
# 1         14
# {'Emissions': 183705830000000.0, 'Cost': 7.3453875, 'Cobenefits': 12580481000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0         28
# 1          2
# {'Emissions': 183996130000000.0, 'Cost': 7.3238883, 'Cobenefits': 12252613000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       9
# 1     hydgn_shift_production_pathways                     2028       9
#
#    max_value
# 0          9
# 1         58
# {'Emissions': 182206390000000.0, 'Cost': 7.464073, 'Cobenefits': 14490054000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       9
# 1     hydgn_shift_production_pathways                     2025       9
#
#    max_value
# 0         69
# 1         93
# {'Emissions': 176374760000000.0, 'Cost': 7.9333243, 'Cobenefits': 20039948000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       8
# 1     hydgn_shift_production_pathways                     2029      10
#
#    max_value
# 0         51
# 1          8
# {'Emissions': 183397130000000.0, 'Cost': 7.369914, 'Cobenefits': 12392560000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       6
# 1     hydgn_shift_production_pathways                     2030       5
#
#    max_value
# 0         71
# 1         24
# {'Emissions': 181792040000000.0, 'Cost': 7.4950438, 'Cobenefits': 12917015000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2028       7
#
#    max_value
# 0         51
# 1         92
# {'Emissions': 179158020000000.0, 'Cost': 7.699842, 'Cobenefits': 17359895000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2029       7
#
#    max_value
# 0         50
# 1         58
# {'Emissions': 180812970000000.0, 'Cost': 7.568387, 'Cobenefits': 14389547000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2026       7
# 1     hydgn_shift_production_pathways                     2027       7
#
#    max_value
# 0         59
# 1         27
# {'Emissions': 181110160000000.0, 'Cost': 7.549116, 'Cobenefits': 13966933000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       5
# 1     hydgn_shift_production_pathways                     2027       5
#
#    max_value
# 0         13
# 1         11
# {'Emissions': 183336940000000.0, 'Cost': 7.3757634, 'Cobenefits': 13134400000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       6
# 1     hydgn_shift_production_pathways                     2029       6
#
#    max_value
# 0          4
# 1         97
# {'Emissions': 180608460000000.0, 'Cost': 7.5882816, 'Cobenefits': 16913066000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029      10
# 1     hydgn_shift_production_pathways                     2025       5
#
#    max_value
# 0         18
# 1          3
# {'Emissions': 183813000000000.0, 'Cost': 7.338676, 'Cobenefits': 12527201000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2027       7
# 1     hydgn_shift_production_pathways                     2026       6
#
#    max_value
# 0         54
# 1         52
# {'Emissions': 179602310000000.0, 'Cost': 7.6745424, 'Cobenefits': 17043228000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2029       5
# 1     hydgn_shift_production_pathways                     2028       6
#
#    max_value
# 0         55
# 1         27
# {'Emissions': 182243620000000.0, 'Cost': 7.4615784, 'Cobenefits': 13759228000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2030       7
# 1     hydgn_shift_production_pathways                     2029       5
#
#    max_value
# 0          0
# 1         50
# {'Emissions': 181920200000000.0, 'Cost': 7.4857197, 'Cobenefits': 14906107000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2025       8
# 1     hydgn_shift_production_pathways                     2029       9
#
#    max_value
# 0          5
# 1         33
# {'Emissions': 183278540000000.0, 'Cost': 7.378882, 'Cobenefits': 13122588000.0}
# reeval
# Running
#                                policy sub_1 sub_2 sub_3  start  max_by  \
# 0  elec_renewable_portfolio_standards                     2028       5
# 1     hydgn_shift_production_pathways                     2029       8
#
#    max_value
# 0         46
# 1         97
# {'Emissions': 181099680000000.0, 'Cost': 7.5514617, 'Cobenefits': 15595918000.0}
# Found 86 optimal policies!

# %%
rhodium.parallel_coordinates(rhodium_model, output)
rhodium.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\pkane\Desktop\EPS Optimizer\Optimizer Notebook Updated.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pkane/Desktop/EPS%20Optimizer/Optimizer%20Notebook%20Updated.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> rhodium.parallel_coordinates(rhodium_model, output)
#       <a href='vscode-notebook-cell:/c%3A/Users/pkane/Desktop/EPS%20Optimizer/Optimizer%20Notebook%20Updated.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> rhodium.plt.show()
#
# File c:\Users\pkane\.conda\envs\prj-lmr-scistack\lib\site-packages\rhodium\plot.py:860, in parallel_coordinates(model, data, c, cols, ax, colors, use_columns, xticks, colormap, target, brush, zorder, **kwds)
#     858     cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap, spacing='proportional', norm=mpl.colors.Normalize(vmin=class_min, vmax=class_max), format='%.2f')
#     859     cb.set_label(c)
# --> 860     cb.set_clim(class_min, class_max)
#     862 mpl.rcParams["axes.facecolor"] = orig_facecolor
#     864 return fig
#
# AttributeError: 'Colorbar' object has no attribute 'set_clim'
